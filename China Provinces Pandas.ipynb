# %%
import pandas as pd

# %%
from IPython.display import Image
Image(filename='China P.png')

# %%
Image(filename='china p2.png')

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/Provinces_of_China')

# %%
table
# Out:
# [                                         0  \
#  0  Province-level administrative divisions
#  1                                      NaN
#  2                                 Category
#  3                                 Location
#  4                                   Number
#  5                              Populations
#  6                                    Areas
#  7                               Government
#  8                             Subdivisions
#
#                                                     1
#  0                                                NaN
#  1                                                NaN
#  2               Unitary one-party socialist republic
#  3                         People's Republic of China
#  4                 33 (not including Taiwan Province)
#  5          552,300 (Macau) – 104,303,132 (Guangdong)
#  6  30.4 km2 (11.7 sq mi) (Macau)[1] – 1,664,897 k...
#  7  Single-Party GovernmentSARs: 1 country, 2 syst...
# ...

# %%
table[9]
# Out:
#                   0                1               2                  3  \
# 0          Province  Provincial seat           Notes                NaN
# 1           English          Chinese          Pinyin            English
# 2             Gansu          甘肅 (甘肃)           Gānsù    Ganzhou Circuit
# 3           Huguang          湖廣 (湖广)         Húguǎng    Wuchang Circuit
# 4     Henanjiangbei             河南江北   Hénánjiāngběi  Bianliang Circuit
# 5           Jiangxi               江西         Jiāngxī   Longxing Circuit
# 6          Jiangzhe               江浙        Jiāngzhè   Hangzhou Circuit
# 7          Liaoyang          遼陽 (辽阳)        Liáoyáng   Liaoyang Circuit
# 8           Lingbei          嶺北 (岭北)         Lǐngběi     Hening Circuit
# 9           Shaanxi          陝西 (陕西)          Shǎnxi   Fengyuan Circuit
# 10          Sichuan               四川         Sìchuān    Chengdu Circuit
# 11           Yunnan          雲南 (云南)          Yúnnán  Zhongqing Circuit
# ...

# %%
table = table[9].dropna(axis=0, thresh=4)

# %%
table.to_excel("China Provinces.xlsx")

# %%
table[0]
# Out:
# 1             English
# 2               Gansu
# 3             Huguang
# 4       Henanjiangbei
# 5             Jiangxi
# 6            Jiangzhe
# 7            Liaoyang
# 8             Lingbei
# 9             Shaanxi
# 10            Sichuan
# 11             Yunnan
# 12          Zhengdong
# 13    Central region*
# 14    Tibetan region*
# Name: 0, dtype: object

# %%
table[1]
# Out:
# 1       Chinese
# 2       甘肅 (甘肃)
# 3       湖廣 (湖广)
# 4          河南江北
# 5            江西
# 6            江浙
# 7       遼陽 (辽阳)
# 8       嶺北 (岭北)
# 9       陝西 (陕西)
# 10           四川
# 11      雲南 (云南)
# 12      征東 (征东)
# 13    中書省 (中书省)
# 14          宣政院
# Name: 1, dtype: object

# %%
table[2]
# Out:
# 1             Pinyin
# 2              Gānsù
# 3            Húguǎng
# 4      Hénánjiāngběi
# 5            Jiāngxī
# 6           Jiāngzhè
# 7           Liáoyáng
# 8            Lǐngběi
# 9             Shǎnxi
# 10           Sìchuān
# 11            Yúnnán
# 12         Zhēngdōng
# 13    Zhōngshū Shěng
# 14    Xuānzhèng Yuàn
# Name: 2, dtype: object

# %%
table[3]
# Out:
# 1               English
# 2       Ganzhou Circuit
# 3       Wuchang Circuit
# 4     Bianliang Circuit
# 5      Longxing Circuit
# 6      Hangzhou Circuit
# 7      Liaoyang Circuit
# 8        Hening Circuit
# 9      Fengyuan Circuit
# 10      Chengdu Circuit
# 11    Zhongqing Circuit
# 12     Kaicheng Circuit
# 13                 none
# 14                 none
# Name: 3, dtype: object

# %%
table[4]
# Out:
# 1                                               Chinese
# 2                                                   甘州路
# 3                                                   武昌路
# 4                                                   汴梁路
# 5                                             龍興路 (龙兴路)
# 6                                                   杭州路
# 7                                             遼陽路 (辽阳路)
# 8                                             和寧路 (和宁路)
# 9                                                   奉元路
# 10                                                  成都路
# 11                                            中慶路 (中庆路)
# 12                                            開城路 (开城路)
# 13    Consist of modern location of Beijing, Tianjin...
# 14    Consist of modern location of Tibet, Qinghai, ...
# Name: 4, dtype: object

# %%
table[5]
# Out:
# 1           Pinyin
# 2       Gānzhōu Lù
# 3       Wǔchāng Lù
# 4     Biànliáng Lù
# 5      Lóngxìng Lù
# 6      Hángzhōu Lù
# 7      Liáoyáng Lù
# 8        Héníng Lù
# 9      Fèngyuán Lù
# 10      Chéngdū Lù
# 11    Zhōngqìng Lù
# 12     Kāichéng Lù
# 13             NaN
# 14             NaN
# Name: 5, dtype: object

# %%
table[6]
# Out:
# 1     Modern location
# 2             Zhangye
# 3               Wuhan
# 4             Kaifeng
# 5            Nanchang
# 6            Hangzhou
# 7            Liaoyang
# 8          Kharkhorin
# 9               Xi'an
# 10            Chengdu
# 11            Kunming
# 12            Kaesong
# 13                NaN
# 14                NaN
# Name: 6, dtype: object

# %%
table[7]
# Out:
# 1                                                   NaN
# 2     Consist of modern location of Gansu, Ningxia, ...
# 3     Consist of modern location of Hunan, Guangxi, ...
# 4     Consist of modern location of Henan, northern ...
# 5     Consist of modern location of Jiangxi & easter...
# 6     Consist of modern location of Shanghai, Zhejia...
# 7     Consist of modern location of Heilongjiang, Ji...
# 8     Consist of modern location of Mongolia & south...
# 9     Consist of modern location of Shaanxi & mid-we...
# 10    Consist of modern location of western Sichuan ...
# 11    Consist of modern location of Yunnan and Upper...
# 12        Consist of modern location of southern Korea.
# 13                                                  NaN
# 14                                                  NaN
# Name: 7, dtype: object
