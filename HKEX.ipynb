# %%
import urllib
import urllib.request
from bs4 import BeautifulSoup

# %%
theurl = "http://www.hkex.com.hk/eng/stat/statrpt/mkthl/mkthl201703.htm"
thepage = urllib.request.urlopen(theurl)
soup = BeautifulSoup(thepage,"html.parser")

# %%
print(soup.title.text)
# Out:
# HKEX Monthly Market Highlights

# %%
# The <a> tag defines a hyperlink, which is used to link from one page to another

# %%
print(soup.findAll('a'))
# Out:
# [<a class="skip-to-content" href="#skip-to-content" title="Skip to Content">Skip to Content</a>, <a class="topbar__logo" href="/?sc_lang=en" title="HKEX"><img alt="hkexlogo" src="/-/media/Market-System/hkexlogo.png"/><span>HKEX</span></a>, <a alt="Small Font Size" class="font-sizes__link font-sizes--small" href="#" title="Small Font Size">A</a>, <a alt="Medium Font Size" class="font-sizes__link font-sizes--medium font-sizes--active" href="#" title="Medium Font Size">A</a>, <a alt="Large Font Size" class="font-sizes__link font-sizes--large" href="#" title="Large Font Size">A</a>, <a class="topbar__link topbar__about-link" href="#" title="About HKEX">About HKEX</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/about-hkex/company-information/about-hkex?sc_lang=en" target="_blank" title="Corporate Information">Corporate Information</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/brand/en/index.htm" target="_blank" title="Our Brand">Our Brand</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/About-HKEX/Organisation/Board-and-Committees?sc_lang=en" target="_blank" title="Organisation">Organisation</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/Investor-Relations?sc_lang=en" target="_blank" title="Investor Relations">Investor Relations</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/Investor-Relations/Regulatory-Disclosure/Regulatory-Reports/2017?sc_lang=en" target="_blank" title="Financial Statements">Financial Statements</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/Investor-Relations?sc_lang=en" target="_blank" title="Real Time Share Price">Real Time Share Price</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/Corporate-Governance?sc_lang=en" target="_blank" title="Corporate Governance">Corporate Governance</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/Corporate-Social-Responsibility?sc_lang=en" target="_blank" title="Corporate  Social Responsibility">Corporate  Social Responsibility</a>, <a class="popover__link " href="/Global/About/Visit-HKEX?sc_lang=en" title="Visit HKEX">Visit HKEX</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/About-HKEX/Careers?sc_lang=en" target="_blank" title="Careers">Careers</a>, <a class="topbar__link topbar__related-sites-link" href="#" title="Related Sites:  LME">Related Sites:  LME</a>, <a class="popover__link topbar__related-sites-icon" href="https://www.lme.com/" target="_blank" title="LME">LME</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexgroup.com/" target="_blank" title="HKEX Group">HKEX Group</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkgem.com/root/e_default.asp" target="_blank" title="GEM">GEM</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.hkexnews.hk/" target="_blank" title="HKEXnews">HKEXnews</a>, <a class="popover__link topbar__related-sites-icon" href="https://www.cesc.com/en/index.html" target="_blank" title="CESC">CESC</a>, <a class="popover__link topbar__related-sites-icon" href="http://www.chinabondconnect.com/en/index.htm" target="_blank" title="Bond Connect">Bond Connect</a>, <a class="topbar__language-one" href="javascript:route('/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-hk', 'zh-HK')" title="Traditional Chinese">繁</a>, <a class="openLightBoxByJS topbar__language-two" data-href="/Global/Disclaimer-For-HanWeb" href="/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-cn" title="Simplified Chinese">简</a>, <a class="topbar__ticker" href="javascript:void(0);" id="header_2_topbarBell" title="Notification"></a>, <a class="sticky-menu__logo" href="/?sc_lang=en" title= ...

# %%
# The <href> tag specifies the URL of the page the link goes to

# %%
for link in soup.findAll('a'):
    print(link.get('href'))
    print(link.text) #related Links
# Out:
# #skip-to-content
# Skip to Content
# /?sc_lang=en
# HKEX
# #
# A
# #
# A
# #
# A
# #
# About HKEX
# http://www.hkexgroup.com/about-hkex/company-information/about-hkex?sc_lang=en
# Corporate Information
# http://www.hkexgroup.com/brand/en/index.htm
# Our Brand
# http://www.hkexgroup.com/About-HKEX/Organisation/Board-and-Committees?sc_lang=en
# Organisation
# http://www.hkexgroup.com/Investor-Relations?sc_lang=en
# Investor Relations
# http://www.hkexgroup.com/Investor-Relations/Regulatory-Disclosure/Regulatory-Reports/2017?sc_lang=en
# Financial Statements
# http://www.hkexgroup.com/Investor-Relations?sc_lang=en
# Real Time Share Price
# http://www.hkexgroup.com/Corporate-Governance?sc_lang=en
# Corporate Governance
# http://www.hkexgroup.com/Corporate-Social-Responsibility?sc_lang=en
# Corporate  Social Responsibility
# /Global/About/Visit-HKEX?sc_lang=en
# Visit HKEX
# http://www.hkexgroup.com/About-HKEX/Careers?sc_lang=en
# Careers
# #
# Related Sites:  LME
# https://www.lme.com/
# LME
# http://www.hkexgroup.com/
# HKEX Group
# http://www.hkgem.com/root/e_default.asp
# GEM
# http://www.hkexnews.hk/
# HKEXnews
# https://www.cesc.com/en/index.html
# CESC
# http://www.chinabondconnect.com/en/index.htm
# Bond Connect
# javascript:route('/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-hk', 'zh-HK')
# 繁
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-cn
# 简
# javascript:void(0);
#
# /?sc_lang=en
#
# #
# Market Data
# /Market-Data/Securities-Prices/Equities?sc_lang=en
# Equities
# /Market-Data/Securities-Prices/Exchange-Traded-Products?sc_lang=en
# Exchange Traded Products
# /Market-Data/Securities-Prices/Derivative-Warrants?sc_lang=en
# Derivative Warrants
# /Market-Data/Securities-Prices/Callable-Bull-Bear-Contracts?sc_lang=en
# Callable Bull / Bear Contracts
# /Market-Data/Securities-Prices/Real-Estate-Investment-Trusts?sc_lang=en
# Real Estate Investment Trusts
# /Market-Data/Securities-Prices/Debt-Securities?sc_lang=en
# Debt Securities
# /Market-Data/Futures-and-Options-Prices/Equity-Index/Hang-Seng-Index-Futures-and-Options?sc_lang=en
# Equity Index
# /Market-Data/Futures-and-Options-Prices/Single-Stock/All?sc_lang=en
# Single Stock
# /Market-Data/Futures-and-Options-Prices/Foreign-Exchange/CUS---USD_CNH-Futures-and-Options?sc_lang=en
# Foreign Exchange
# /Market-Data/Futures-and-Options-Prices/Interest-Rate/One-Month-HIBOR-Futures?sc_lang=en
# Interest Rate
# /Market-Data/Futures-and-Options-Prices/Commodities/Gold-Futures?sc_lang=en
# Commodities
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# Consolidated Reports
# /Market-Data/Statistics/Securities-Market?sc_lang=en
# Securities Market
# /Market-Data/Statistics/Derivatives-Market?sc_lang=en
# Derivatives Market
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# Participant
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository?sc_lang=en
# Clearing, Settlement and Depository
# /Market-Data/HKEX-News?sc_lang=en
# HKEXnews
# /Market-Data/News-Alerts?sc_lang=en
# News Alerts
# /Services/Market-Data-Services?sc_lang=en
# Market Data Services
# /Market-Data/HKEX-News?sc_lang=en
#
# /Market-Data/HKEX-News?sc_lang=en
# HKEXnews
# /Market-Data/News-Alerts?sc_lang=en
#
# /Market-Data/News-Alerts?sc_lang=en
# News Alerts
# /Services/Market-Data-Services?sc_lang=en
#
# /Services/Market-Data-Services?sc_lang=en
# Market Data Services
# #
# Products
# /Products/Securities/Equities?sc_lang=en
# Equities
# /Products/Securities/Exchange-Traded-Products/Overview?sc_lang=en
# Exchange Traded Products
# /Products/Securities/Derivative-Warrants?sc_lang=en
# Derivative Warrants
# /Products/Securities/Callable-Bull-Bear-Contracts?sc_lang=en
# Callable Bull / Bear Contracts
# /Products/Securities/Real-Estate-Investment-Trusts?sc_lang=en
# Real Estate Investment Trusts
# /Products/Securities/Debt-Securities?sc_lang=en
# Debt Securities
# /Products/Listed-Derivatives/Equity-Index/Hang-Seng-Index-(HSI)/Hang-Seng-Index-Futures?sc_lang=en
# Equity Index
# /Products/Listed-Derivatives/Single-Stock/Stock-Futures?sc_lang=en
# Single Stock
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Futures?sc_lang=en
# Foreign Exchange
# /Products/Listed-Derivatives/Interest-Rate/Three-Months-HIBOR-Futures?sc_lang=en
# Interest Rate
# /Products/Listed-Derivatives/Commodities/Gold-Futures?sc_lang=en
# Commodities
# /Products/OTC-Derivatives/Eligible-OTC-Clear-Products?sc_lang=en
# Eligible OTC Clear Products
# /Products/OTC-Derivatives/Interest-Rate-Swaps?sc_lang=en
# Interest Rate Swaps
# /Products/OTC-Derivatives/Non-Deliverable-Forwards?sc_lang=en
# Non Deliverable Forwards
# /Products/OTC-Derivatives/Cross-Currency-Swaps?sc_lang=en
# Cross Currency Swaps
# /Products/OTC-Derivatives/Deliverable-FX?sc_lang=en
# Deliverable FX
# /Products/Find-a-Partner?sc_lang=en
# Find a Partner
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
# USD/CNH Gold Futures
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
# RMB Currency Options
# /Products/Find-a-Partner?sc_lang=en
#
# /Products/Find-a-Partner?sc_lang=en
# Find a Partner
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
#
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
# USD/CNH Gold Futures
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
#
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
# RMB Currency Options
# #
# Services
# /Services/Trading/Securities/Overview/Trading-Mechanism?sc_lang=en
# Overview
# /Services/Trading/Securities/Infrastructure/Overview?sc_lang=en
# Infrastructure
# /Services/Trading/Derivatives/Overview/Trading-Mechanism?sc_lang=en
# Overview
# /Services/Trading/Derivatives/Infrastructure/HKATS?sc_lang=en
# Infrastructure
# /Services/Connectivity/Hosting-Services?sc_lang=en
# Hosting Services
# /Services/Connectivity/SDNet-2?sc_lang=en
# SDNet/2
# /Services/Market-Data-Services/Real-Time-Data-Services/Overview?sc_lang=en
# Real Time Data Services
# /Services/Market-Data-Services/Historical-Data-Services?sc_lang=en
# Historical Data Services
# /Services/Market-Data-Services/Infrastructure?sc_lang=en
# Infrastructure
# /Services/Rules-and-Forms-and-Fees/Rules/Overview?sc_lang=en
# Rules
# /Services/Rules-and-Forms-and-Fees/Forms/Overview?sc_lang=en
# Forms
# /Services/Rules-and-Forms-and-Fees/Fees/Overview?sc_lang=en
# Fees
# /Services/Clearing/Securities/Overview?sc_lang=en
# Overview
# /Services/Clearing/Securities/Infrastructure?sc_lang=en
# Infrastructure
# /Services/Clearing/Securities/Risk-Management?sc_lang=en
# Risk Management
# /Services/Clearing/Securities/PFMI?sc_lang=en
# PFMI
# /Services/Clearing/Listed-Derivatives/Overview?sc_lang=en
# Overview
# /Services/Clearing/Listed-Derivatives/Infrastructure?sc_lang=en
# Infrastructure
# /Services/Clearing/Listed-Derivatives/Risk-Management?sc_lang=en
# Risk Management
# /Services/Clearing/Listed-Derivatives/PFMI?sc_lang=en
# PFMI
# /Services/Clearing/OTC-Clear/Overview/Clearing-Services?sc_lang=en
# Overview
# /Services/Clearing/OTC-Clear/Infrastructure?sc_lang=en
# Infrastructure
# /Services/Clearing/OTC-Clear/Risk-Management?sc_lang=en
# Risk Management
# /Services/Clearing/OTC-Clear/PFMI?sc_lang=en
# PFMI
# /Services/Settlement-and-Depository/Settlement?sc_lang=en
# Settlement - Securities
# /Services/Settlement-and-Depository/Depository?sc_lang=en
# Depository
# /Services/Settlement-and-Depository/Common-Nominee-Services?sc_lang=en
# Common Nominee Services
# /Services/Settlement-and-Depository/Securities-Admission-into-CCASS?sc_lang=en
# Securities Admission into CCASS
# /Services/Clearing/Securities/PFMI?sc_lang=en
# PFMI
# /Services/Next-Generation-Post-Trade-Programme/Overview?sc_lang=en
# Overview
# /Services/Next-Generation-Post-Trade-Programme/NextGen-Risk-Management?sc_lang=en
# NextGen Risk Management
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# Circulars & Notices
# /Services/Become-a-Participant?sc_lang=en
# Become a Participant
# /Services/Market-Open-Ceremony?sc_lang=en
# Market Open/Closing Ceremonies
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
#
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# Circulars & Notices
# /Services/Become-a-Participant?sc_lang=en
#
# /Services/Become-a-Participant?sc_lang=en
# Become a Participant
# /Services/Market-Open-Ceremony?sc_lang=en
#
# /Services/Market-Open-Ceremony?sc_lang=en
# Market Open/Closing Ceremonies
# #
# Listing
# /Listing/Why-List-in-Hong-Kong?sc_lang=en
# Why List in Hong Kong
# /Listing/Getting-Started?sc_lang=en
# Getting Started
# /Listing/How-We-Regulate/Overview?sc_lang=en
# How We Regulate
# /Listing/Rules-and-Guidance/Whats-New?sc_lang=en
# Rules and Guidance
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
# Listing in Hong Kong
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
# Listing Rules
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
# Contact Us
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
#
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
# Listing in Hong Kong
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
#
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
# Listing Rules
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
#
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
# Contact Us
# #
# News
# /News/News-Release?sc_lang=en
# News Releases
# /News/Market-Consultations/2016-to-Present?sc_lang=en
# Market Consultations
# /News/Tender-Notices/Tender-Notices?sc_lang=en
# Tender Notices
# /News/Research-Reports/HKEX-Surveys/HKEX-Surveys?sc_lang=en
# Research Reports
# http://www.hkexgroup.com/Media-Centre?sc_lang=en
# Media Centre
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
# Charles Li Direct
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# Circulars & Notices
# /News/HKEX-Calendar?sc_lang=en
# HKEX Calendar
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
#
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
# Charles Li Direct
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
#
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# Circulars & Notices
# /News/HKEX-Calendar?sc_lang=en
#
# /News/HKEX-Calendar?sc_lang=en
# HKEX Calendar
# #
# Mutual Market
# /Mutual-Market/Stock-Connect?sc_lang=en
# Stock Connect
# http://www.chinabondconnect.com
# Bond Connect
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
# Daily Statistics
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
# Market Highlights
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
# Eligible Securities
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
#
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
# Daily Statistics
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
#
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
# Market Highlights
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
#
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
# Eligible Securities
# None
# Search
# javascript:route('/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-hk', 'zh-HK')
# 繁
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-cn
# 简
# ../../../layouts/HKEX/HKEX%20MARKET/#
# a
# ../../../layouts/HKEX/HKEX%20MARKET/#
# a
# ../../../layouts/HKEX/HKEX%20MARKET/#
# a
# ../../../layouts/HKEX/HKEX%20MARKET/#
# About HKEX
# ../../../layouts/HKEX/HKEX%20MARKET/#
# Related Sites:  LME
# javascript:void(0);
# Notification
# None
# Cancel
# #
# Market Data
# #
# Statistics
# /Market-Data/Statistics/Consolidated-Reports?sc_lang=en
# Consolidated Reports
# #
# Market Data
# #
# Statistics
# /Market-Data/Statistics/Consolidated-Reports?sc_lang=en
# Consolidated Reports
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# Consolidated Reports
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# HKEX Monthly Market Highlights
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Securities-and-Derivatives-Markets-Quarterly-Report?sc_lang=en
# HKEX Securities and Derivatives Markets Quarterly Report
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Fact-Book?sc_lang=en
# HKEX Fact Book
# /Market-Data/Statistics/Consolidated-Reports/Monthly-Bulletin?sc_lang=en
# Monthly Bulletin (Main Board)
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive?sc_lang=en
# Securities Statistics Archive (Main Board)
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/Trading-value,-volume-and-number-of-deals/2015-to-2018-(up-to-the-end-of-previous-month)?sc_lang=en
# Trading value, volume and number of deals
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/Market-capitalisation/2015-to-2018-(up-to-the-end-of-previous-month)_mc?sc_lang=en
# Market capitalisation
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/S,-a-,P-HKEX-LargeCap-Index-daily-closing/2018-(up-to-the-end-of-previous-month)_sp?sc_lang=en
# S&P;/HKEX LargeCap Index - daily closing
# http://www.hkgem.com/statistics/e_default.htm
# Growth Enterprise Market (GEM)
# /Market-Data/Statistics/Consolidated-Reports/China-Dimension?sc_lang=en
# China Dimension
# /Market-Data/Statistics/Securities-Market?sc_lang=en
# Securities Market
# /-/media/HKEX-Market/Market-Data/Statistics/Securities-Market/Funds-Raised-by-Type/fun_type_e.pdf
# Funds Raised by Type
# /Market-Data/Statistics/Securities-Market/Placings?sc_lang=en
# Placings
# /Market-Data/Statistics/Securities-Market/Takeovers?sc_lang=en
# Takeovers
# /eng/stat/smstat/dayquot/qtn.asp
# Daily Quotations (Main Board)
# /Market-Data/Statistics/Securities-Market/Short-Selling-Turnover-Today?sc_lang=en
# Short Selling Turnover Today
# /eng/stat/smstat/ssturnover/ncms/mshtmain.htm
# Short Selling Turnover (Main Board) up to morning close today
# /eng/stat/smstat/ssturnover/ncms/mshtgem.htm
# Short Selling Turnover (GEM) up to morning close today
# /eng/stat/smstat/ssturnover/ncms/mshten.htm
# Short Selling Turnover (NASDAQ Stocks) up to morning close today
# /eng/stat/smstat/ssturnover/ncms/ashtmain.htm
# Short Selling Turnover (Main Board) up to day close today
# /eng/stat/smstat/ssturnover/ncms/ashtgem.htm
# Short Selling Turnover (GEM) up to day close today
# /eng/stat/smstat/ssturnover/ncms/ashten.htm
# Short Selling Turnover (NASDAQ Stocks) up to day close today
# /eng/vcm/vcmtriggersecurity.aspx
# VCM (Securities Market) Cooling-off Period Trigger History
# /Market-Data/Statistics/Derivatives-Market?sc_lang=en
# Derivatives Market
# /Market-Data/Statistics/Derivatives-Market/Derivatives-Market-Highlights?sc_lang=en
# Derivatives Market Highlights
# /Market-Data/Statistics/Derivatives-Market/Daily-Statistics?sc_lang=en
# Daily Statistics
# /Market-Data/Statistics/Derivatives-Market/Monthly-Statistics?sc_lang=en
# Monthly Statistics
# /Market-Data/Statistics/Derivatives-Market/Yearly-Statistics?sc_lang=en
# Yearly Statistics
# /Market-Data/Statistics/Derivatives-Market/Record-High?sc_lang=en
# Record High
# /eng/vcm/vcmtriggerderivative.aspx
# VCM (Derivatives Market) Cooling-off Period Trigger History
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports?sc_lang=en
# Market Research Reports
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/Derivatives-Market?sc_lang=en
# Equity Derivatives Market
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/USD-CNH-Futures?sc_lang=en
# USD/CNH Futures
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/FIC-Monthly-Newsletter?sc_lang=en
# FIC Monthly Newsletter
# /Market-Data/Statistics/Derivatives-Market/Daily-Market-Report-(Latest)?sc_lang=en
# Daily Market Report (Latest)
# /eng/stat/dmstat/dayrpt/dmrcalendar.asp
# Daily Market Report (Archive)
# /eng/stat/dmstat/dayrpt/stkoptexe.htm
# Summary of Stock Options Exercised
# /eng/stat/dmstat/wqtn.asp
# Weekly Quotations (Stock Options)
# /Market-Data/Statistics/Derivatives-Market/Market-Share-Data-on-HSI-Futures?sc_lang=en
# Market Share Data on HSI Futures
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# Participant
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# Stock Exchange Participants' Market Share Report
# /Market-Data/Statistics/Participant/Exchange-Participant-Data?sc_lang=en
# Exchange Participant Data
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository?sc_lang=en
# Clearing, Settlement and Depository
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Clearing-Statistics?sc_lang=en
# Securities Clearing Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Margin-Requirement?sc_lang=en
# Securities Margin Requirement
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Settlement-Statistics?sc_lang=en
# Securities Settlement Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Stock-Admission-Statistics?sc_lang=en
# Stock Admission Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics?sc_lang=en
# Listed Derivatives Clearing Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics/Listed-Derivatives-Margin-Requirement?sc_lang=en
# Listed Derivatives Margin Requirement
# /eng/stat/dmstat/oi/oi_f.asp
# Daily Trading Activity & Open Positions Summary (Futures & Index Options)
# /eng/stat/dmstat/oi/oi_o.asp
# Daily Trading Activity & Open Positions Summary (Stock Options)
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics/Data-Download?sc_lang=en
# Data Download
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics?sc_lang=en
# OTC Clearing and Settlement Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics/Monthly-Statistics?sc_lang=en
# Monthly Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics/Yearly-Statistics?sc_lang=en
# Yearly Statistics
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Depository-Statistics?sc_lang=en
# Securities Depository Statistics
# #
# September 2018
# #
# September 2018
# #
# August 2018
# #
# July 2018
# #
# June 2018
# #
# May 2018
# #
# April 2018
# #
# March 2018
# #
# February 2018
# #
# January 2018
# #
# December 2017
# #
# November 2017
# #
# October 2017
# #
# September 2017
# https://www.hkex.com.hk/-/media/HKEX-Market/Services/Rules-and-Forms-and-Fees/Rules/SEHK/Securities/Rules/chap_1_eng.pdf?la=en
# (ATS) transactions
# /?sc_lang=en
#
# /Global/Exchange/Contact?sc_lang=en
# Contact
# http://www.hkexgroup.com/About-HKEX/Careers
# Career
# /Global/Exchange/FAQ/Top-Questions?sc_lang=en
# FAQ
# /Global/Exchange/Sitemap?sc_lang=en
# Sitemap
# /Global/Exchange/Glossary?sc_lang=en
# Glossary
# /Global/Exchange/Disclaimer?sc_lang=en
# Disclaimer
# /Global/Exchange/Hyperlink-Policy?sc_lang=en
# Hyperlink Policy
# /Global/Exchange/Privacy-Policy?sc_lang=en
# Privacy Policy
# /Global/Exchange/Website-Tutorials?sc_lang=en
# Website Tutorials
# /Services/RSS-Feeds?sc_lang=en
# RSS

# %%
print(soup.findAll('a')[0])
# Out:
# <a class="skip-to-content" href="#skip-to-content" title="Skip to Content">Skip to Content</a>

# %%
print(soup.findAll('a')[1])
# Out:
# <a class="topbar__logo" href="/?sc_lang=en" title="HKEX"><img alt="hkexlogo" src="/-/media/Market-System/hkexlogo.png"/><span>HKEX</span></a>

# %%
print(soup.find('a'))
# Out:
# <a class="skip-to-content" href="#skip-to-content" title="Skip to Content">Skip to Content</a>

# %%
for url in soup.find_all('a'):
    print(url.text)
# Out:
# Skip to Content
# HKEX
# A
# A
# A
# About HKEX
# Corporate Information
# Our Brand
# Organisation
# Investor Relations
# Financial Statements
# Real Time Share Price
# Corporate Governance
# Corporate  Social Responsibility
# Visit HKEX
# Careers
# Related Sites:  LME
# LME
# HKEX Group
# GEM
# HKEXnews
# CESC
# Bond Connect
# 繁
# 简
#
#
# Market Data
# Equities
# Exchange Traded Products
# Derivative Warrants
# Callable Bull / Bear Contracts
# Real Estate Investment Trusts
# Debt Securities
# Equity Index
# Single Stock
# Foreign Exchange
# Interest Rate
# Commodities
# Consolidated Reports
# Securities Market
# Derivatives Market
# Participant
# Clearing, Settlement and Depository
# HKEXnews
# News Alerts
# Market Data Services
#
# HKEXnews
#
# News Alerts
#
# Market Data Services
# Products
# Equities
# Exchange Traded Products
# Derivative Warrants
# Callable Bull / Bear Contracts
# Real Estate Investment Trusts
# Debt Securities
# Equity Index
# Single Stock
# Foreign Exchange
# Interest Rate
# Commodities
# Eligible OTC Clear Products
# Interest Rate Swaps
# Non Deliverable Forwards
# Cross Currency Swaps
# Deliverable FX
# Find a Partner
# USD/CNH Gold Futures
# RMB Currency Options
#
# Find a Partner
#
# USD/CNH Gold Futures
#
# RMB Currency Options
# Services
# Overview
# Infrastructure
# Overview
# Infrastructure
# Hosting Services
# SDNet/2
# Real Time Data Services
# Historical Data Services
# Infrastructure
# Rules
# Forms
# Fees
# Overview
# Infrastructure
# Risk Management
# PFMI
# Overview
# Infrastructure
# Risk Management
# PFMI
# Overview
# Infrastructure
# Risk Management
# PFMI
# Settlement - Securities
# Depository
# Common Nominee Services
# Securities Admission into CCASS
# PFMI
# Overview
# NextGen Risk Management
# Circulars & Notices
# Become a Participant
# Market Open/Closing Ceremonies
#
# Circulars & Notices
#
# Become a Participant
#
# Market Open/Closing Ceremonies
# Listing
# Why List in Hong Kong
# Getting Started
# How We Regulate
# Rules and Guidance
# Listing in Hong Kong
# Listing Rules
# Contact Us
#
# Listing in Hong Kong
#
# Listing Rules
#
# Contact Us
# News
# News Releases
# Market Consultations
# Tender Notices
# Research Reports
# Media Centre
# Charles Li Direct
# Circulars & Notices
# HKEX Calendar
#
# Charles Li Direct
#
# Circulars & Notices
#
# HKEX Calendar
# Mutual Market
# Stock Connect
# Bond Connect
# Daily Statistics
# Market Highlights
# Eligible Securities
#
# Daily Statistics
#
# Market Highlights
#
# Eligible Securities
# Search
# 繁
# 简
# a
# a
# a
# About HKEX
# Related Sites:  LME
# Notification
# Cancel
# Market Data
# Statistics
# Consolidated Reports
# Market Data
# Statistics
# Consolidated Reports
# Consolidated Reports
# HKEX Monthly Market Highlights
# HKEX Securities and Derivatives Markets Quarterly Report
# HKEX Fact Book
# Monthly Bulletin (Main Board)
# Securities Statistics Archive (Main Board)
# Trading value, volume and number of deals
# Market capitalisation
# S&P;/HKEX LargeCap Index - daily closing
# Growth Enterprise Market (GEM)
# China Dimension
# Securities Market
# Funds Raised by Type
# Placings
# Takeovers
# Daily Quotations (Main Board)
# Short Selling Turnover Today
# Short Selling Turnover (Main Board) up to morning close today
# Short Selling Turnover (GEM) up to morning close today
# Short Selling Turnover (NASDAQ Stocks) up to morning close today
# Short Selling Turnover (Main Board) up to day close today
# Short Selling Turnover (GEM) up to day close today
# Short Selling Turnover (NASDAQ Stocks) up to day close today
# VCM (Securities Market) Cooling-off Period Trigger History
# Derivatives Market
# Derivatives Market Highlights
# Daily Statistics
# Monthly Statistics
# Yearly Statistics
# Record High
# VCM (Derivatives Market) Cooling-off Period Trigger History
# Market Research Reports
# Equity Derivatives Market
# USD/CNH Futures
# FIC Monthly Newsletter
# Daily Market Report (Latest)
# Daily Market Report (Archive)
# Summary of Stock Options Exercised
# Weekly Quotations (Stock Options)
# Market Share Data on HSI Futures
# Participant
# Stock Exchange Participants' Market Share Report
# Exchange Participant Data
# Clearing, Settlement and Depository
# Securities Clearing Statistics
# Securities Margin Requirement
# Securities Settlement Statistics
# Stock Admission Statistics
# Listed Derivatives Clearing Statistics
# Listed Derivatives Margin Requirement
# Daily Trading Activity & Open Positions Summary (Futures & Index Options)
# Daily Trading Activity & Open Positions Summary (Stock Options)
# Data Download
# OTC Clearing and Settlement Statistics
# Monthly Statistics
# Yearly Statistics
# Securities Depository Statistics
# September 2018
# September 2018
# August 2018
# July 2018
# June 2018
# May 2018
# April 2018
# March 2018
# February 2018
# January 2018
# December 2017
# November 2017
# October 2017
# September 2017
# (ATS) transactions
#
# Contact
# Career
# FAQ
# Sitemap
# Glossary
# Disclaimer
# Hyperlink Policy
# Privacy Policy
# Website Tutorials
# RSS

# %%
print(soup.title)
# Out:
# <title>HKEX Monthly Market Highlights</title>

# %%
print(soup.get_text())
# Out:
# HKEX Monthly Market Highlights
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         function browserCheck() {
#             if (checkMode() != 'pageeditor' && checkMode() != 'preview') {
#                 //DisplayLang();
#                 var dest = '' + window.parent.location;
#
#                 if (dest.toLowerCase().indexOf('/tunis/') == -1 && dest.toLowerCase().indexOf('sc_lang=zh-cn') != -1) { //[/sc.hkex.com.hk/tunis/]
#                     var RegExLangZhCn = new RegExp("sc_lang=zh-cn", "ig");
#
#                     dest = dest.toLowerCase().replace(RegExLangZhCn, "sc_lang=zh-hk");
#                     window.parent.location = dest;
#                 }
#             }
#             if (!browserAllow()) {
#                 alert('Your browser version is incompatible with our website. Please update your browser to Internet Explorer 9 or later.');
#             }
#         }
#
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-51785376-1', 'auto');
#         ga('send', 'pageview');
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NZFRCR');
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     var $ = jQuery.noConflict();
#     (function ($) {
#         $(function () {
#             if (typeof (LabCI) === "undefined") LabCI = {};
#
#             // For returning the access token
#             LabCI.getToken = function () {
#                 // ----- THIS IS A SAMPLE IMPLEMENTATION -----
#                 //return "Base64-AES-Encrypted-Token";
#                 return "evLtsLsBNAUVTPxtGqVeG7hYIllRogYcbuEzAMCJGb36%2fx0BthJva3slGDjG17t8";
#             };
#
#             // For returning the current UI language
#             LabCI.getLang = function () {
#                 // ----- THIS IS A SAMPLE IMPLEMENTATION -----
#                 return "en";
#             };
#         });
#     })(jQuery);
#
#
#
#     if (checkMode() != 'pageeditor') {
#         var msgEntKeyword = "Please enter the search keyword.";
#
#         function validateGlobalSearchKeyword(device) {
#             if (device == 'desktop') {
#                 if ($("#inputSearch").val() == "") {
#                     alert(msgEntKeyword);
#                     return false;
#                 } else {
#                     redirect(encodeURIComponent($("#inputSearch").val()));
#                 }
#             } else {
#                 if ($("#mobileSearchInput").val() == "") {
#                     alert(msgEntKeyword);
#                     return false;
#                 } else {
#                     redirect(encodeURIComponent($("#mobileSearchInput").val()));
#                 }
#             }
#         }
#
#         function redirect(keyword) {
#             setTimeout(function () {
#                 var pageUrl = "/Global/HKEX-Market-Search-Result?sc_lang=en";
#                 var filterUrl = "Market Data|Products|Services|Listing|News|FAQ|Global";
#                 var trCallbackFunction = "searchKeydownAction";
#                 if ($('.market-hkex .header-result table tr:nth-child(1) td:nth-child(1)').length > 0)
#                     window.location = pageUrl + "&mode=basic&q=" + keyword + "&u=" + filterUrl + "&sym=" + $('.market-hkex .header-result table tr:nth-child(1) td:nth-child(1)').html() + "&callback=" + trCallbackFunction + "&qid=" + Date.now();
#                 else if ($('.market-hkex .headermm-result table tr:nth-child(1) td:nth-child(1)').length > 0)
#                     window.location = pageUrl + "&mode=basic&q=" + keyword + "&u=" + filterUrl + "&sym=" + $('.market-hkex .headermm-result table tr:nth-child(1) td:nth-child(1)').html() + "&callback=" + trCallbackFunction + "&qid=" + Date.now();
#                 else if ($('.market-hkex .headerm-result table tr:nth-child(1) td:nth-child(1)').length > 0)
#                     window.location = pageUrl + "&mode=basic&q=" + keyword + "&u=" + filterUrl + "&sym=" + $('.market-hkex .headerm-result table tr:nth-child(1) td:nth-child(1)').html() + "&callback=" + trCallbackFunction + "&qid=" + Date.now();
#                 else
#                     window.location = pageUrl + "&mode=basic&q=" + keyword + "&u=" + filterUrl;
#             }, 500);
#         }
#
#         function GlobalSearch(e,device) {
#             if (e.keyCode == 13 || e.which == 13) {
#                 validateGlobalSearchKeyword(device);
#                 return false;
#             } else {
#                 return true;
#             }
#         }
#         function hideLanguageButton(lang) {
#         }
#     }
#
#     function getParameterByName(name) {
#         var url = window.location.href;
#         url = url.split("#").join("&");
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&#]" + name + "(=([^&#]*)|&|#|$)"),
#             results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#     }
#
#     $(document).ready(function () {
#         if (jQuery("div").hasClass("ticker")) {
#             var tickerResult = false;
#             jQuery(".ticker").each(function () {
#                 if ($(this).css("display") == "none") {
#                     tickerResult = true;
#                 }
#             });
#
#             if (tickerResult) {
#                 jQuery(".market-hkex .topbar__ticker").css("background", "url('/Images/HKEX/HKEX MARKET/topbar_bell_hover.png') no-repeat left center");
#             }
#             else {
#                 jQuery(".market-hkex .topbar__ticker").css("background", "url('/Images/HKEX/HKEX MARKET/topbar_bell.png') no-repeat left center");
#             }
#         }
#         else {
#             jQuery(".market-hkex .topbar__ticker").css("background", "url('/Images/HKEX/HKEX MARKET/topbar_bell.png') no-repeat left center");
#         }
#
#         if (getParameterByName('sc_lang').toLowerCase() == 'en')
#             $('.market-hkex .header-result').attr('lang', 'en');
#         else if (getParameterByName('sc_lang').toLowerCase() == 'zh-hk')
#             $('.market-hkex .header-result').attr('lang', 'zh-HK');
#         else
#             $('.market-hkex .header-result').attr('lang', 'zh-cn');
#
#         if (getParameterByName('sc_lang').toLowerCase() == 'zh-cn') {
#             $('.market-hkex .topbar__related-sites-popover .popover__list-item .popover__link').each(function () {
#                 $(this).attr('href', $(this).attr('href').replace('sc_lang=zh-HK', 'sc_lang=zh-cn'));
#             });
#         }
#
#         $(window).on("resize", function () {
#             stockCodePosition();
#         });
#
#         function stockCodePosition() {
#             if ($(window).width() > 1440) {
#                 $('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('right', '');
#                 var tblMargin = parseInt($('.market-hkex .container.topbar__container').css('margin-left').replace('px', ''));
#                 var tblRight = parseInt($('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('right').replace('px', ''));
#                 $('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('right', (tblMargin + tblRight) + 'px');
#
#             }
#             else {
#                 $('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('right', '');
#             }
#
#             if ($('.header-tags').position().top > 20)
#                 $('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('top', '157px');
#             else
#                 $('.market-hkex .lg-topbar__side.topbar__side.header-searchbox .header-result').css('top', '');
#
#         }
#
#         stockCodePosition();
#     });
#
#
#
#
#
# Search Website
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to Content
# HKEX
#
#
#
# Font Size
# A
# A
# A
#
#
# About HKEX
#
#
#
# Corporate InformationOur BrandOrganisationInvestor RelationsFinancial StatementsReal Time Share PriceCorporate GovernanceCorporate  Social ResponsibilityVisit HKEXCareers
#
#
#
#
#
# Related Sites:  LME
#
#
#
# LMEHKEX GroupGEMHKEXnewsCESCBond Connect
#
#
#
#
#
# Search Website
#
# 繁
# 简
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Data$('.mega-menu .forMobileQuoteLookup #mobile_quotelookup').load('/lhkexw/ui/powersearchm.html');Securities PricesEquitiesExchange Traded ProductsDerivative WarrantsCallable Bull / Bear ContractsReal Estate Investment TrustsDebt SecuritiesFutures & Options PricesEquity IndexSingle StockForeign ExchangeInterest RateCommoditiesStatisticsConsolidated ReportsSecurities MarketDerivatives MarketParticipantClearing, Settlement and DepositoryHKEXnewsNews AlertsMarket Data ServicesHKEXnewsView listed company announcements and more on the centralised platform for regulatory filings and disclosuresNews AlertsSign up to receive company announcements or website updates by emailMarket Data ServicesVendors can sign up to purchase wholesale market data from HKEX’s Market Data Services departmentProductsSecuritiesEquitiesExchange Traded ProductsDerivative WarrantsCallable Bull / Bear ContractsReal Estate Investment TrustsDebt SecuritiesListed DerivativesEquity IndexSingle StockForeign ExchangeInterest RateCommoditiesOTC DerivativesEligible OTC Clear ProductsInterest Rate SwapsNon Deliverable ForwardsCross Currency SwapsDeliverable FXFind a PartnerUSD/CNH Gold FuturesRMB Currency OptionsFind a PartnerSearch our directory to find brokers, clearing members, information vendors and moreUSD/CNH Gold FuturesThe first pair of dual currency and physically-settled gold futures contracts in Hong KongRMB Currency OptionsYour new option to manage RMB currency risksServicesTradingSecuritiesOverviewInfrastructureDerivativesOverviewInfrastructureConnectivityHosting ServicesSDNet/2Market Data ServicesReal Time Data ServicesHistorical Data ServicesInfrastructureRules, Forms & FeesRulesFormsFeesClearingSecuritiesOverviewInfrastructureRisk ManagementPFMIListed DerivativesOverviewInfrastructureRisk ManagementPFMIOTC ClearOverviewInfrastructureRisk ManagementPFMISettlement and DepositorySettlement - SecuritiesDepositoryCommon Nominee ServicesSecurities Admission into CCASSPFMINextGen Post Trade ProgrammeOverviewNextGen Risk ManagementCirculars & NoticesBecome a ParticipantMarket Open/Closing CeremoniesCirculars & NoticesView important information issued by HKEX to Exchange and Clearing House Participants, Market Data vendors and Hosting Services membersBecome a ParticipantConnect to Hong Kong’s financial market through HKEXMarket Open/Closing CeremoniesLearn how your company can bang the gong to officially open trading on HKEX’s marketsListingWhy List in Hong KongGetting StartedHow We RegulateRules and GuidanceListing in Hong KongListing RulesContact UsListing in Hong KongGet started on the path to listing on HKEX’s markets.Listing RulesThe Listing Rules for the Main Board and GEM of the Stock Exchange of Hong KongContact UsGet in touch with our Listing DepartmentNewsNews ReleasesMarket ConsultationsTender NoticesResearch ReportsMedia CentreCharles Li DirectCirculars & NoticesHKEX CalendarCharles Li DirectMarket insights from HKEX Chief Executive Charles LiCirculars & NoticesView important information issued by HKEX to Exchange and Clearing House Participants, Market Data vendors and Hosting Services membersHKEX CalendarDownload or subscribe to our calendar containing trading and clearing information, public holidays and moreMutual MarketStock ConnectBond ConnectDaily StatisticsMarket HighlightsEligible SecuritiesDaily StatisticsStatistics on Shanghai and Shenzhen Connect updated dailyMarket HighlightsView the market capitalization, number of listed companies and more in the Hong Kong, Shanghai and Shenzhen marketsEligible SecuritiesA list of securities eligible for trading under Shanghai and Shenzhen Stock Connect
#
# Search
#
#
#
#
#
# 繁
# 简
#
#
#
# Font Size
# a
# a
# a
#
#
# About HKEX
#
#
# Related Sites:  LME
#
#
# Notification
#
#
#
#
#
# Cancel
# Search Website
#
#
#
#
#
#
#
# Market DataStatisticsConsolidated Reports
#
#
#
#
#
#
#
#
#
# Market DataStatisticsConsolidated Reports
#
#
#
#                         HKEX Monthly Market Highlights
#
#
#
#
#
#
#
#
#
# StatisticsConsolidated ReportsConsolidated ReportsConsolidated ReportsHKEX Monthly Market HighlightsHKEX Securities and Derivatives Markets Quarterly ReportHKEX Fact BookMonthly Bulletin (Main Board)Securities Statistics Archive (Main Board)Trading value, volume and number of dealsMarket capitalisationS&P;/HKEX LargeCap Index - daily closingGrowth Enterprise Market (GEM)China DimensionSecurities MarketSecurities MarketFunds Raised by TypePlacingsTakeoversDaily Quotations (Main Board)Short Selling Turnover TodayShort Selling Turnover (Main Board) up to morning close todayShort Selling Turnover (GEM) up to morning close todayShort Selling Turnover (NASDAQ Stocks) up to morning close todayShort Selling Turnover (Main Board) up to day close todayShort Selling Turnover (GEM) up to day close todayShort Selling Turnover (NASDAQ Stocks) up to day close todayVCM (Securities Market) Cooling-off Period Trigger HistoryDerivatives MarketDerivatives MarketDerivatives Market HighlightsDaily StatisticsMonthly StatisticsYearly StatisticsRecord HighVCM (Derivatives Market) Cooling-off Period Trigger HistoryMarket Research ReportsEquity Derivatives MarketUSD/CNH FuturesFIC Monthly NewsletterDaily Market Report (Latest)Daily Market Report (Archive)Summary of Stock Options ExercisedWeekly Quotations (Stock Options)Market Share Data on HSI FuturesParticipantParticipantStock Exchange Participants' Market Share ReportExchange Participant DataClearing, Settlement and DepositoryClearing, Settlement and DepositorySecurities Clearing StatisticsSecurities Margin RequirementSecurities Settlement StatisticsStock Admission StatisticsListed Derivatives Clearing StatisticsListed Derivatives Margin RequirementDaily Trading Activity & Open Positions Summary (Futures & Index Options)Daily Trading Activity & Open Positions Summary (Stock Options)Data DownloadOTC Clearing and Settlement StatisticsMonthly StatisticsYearly StatisticsSecurities Depository Statistics
#
#
#
#
#
# HKEX Monthly Market Highlights
#
#
#     function firstDropdownChange() {
#         var pageUrl = "/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en";
#
#         var firstlistselect = $("#select-target-firstdropdownlist").attr('data-id');
#         pageUrl += (pageUrl.indexOf("?") != -1 ? "&" : "?") + "select=" + firstlistselect ;
#         window.parent.location = pageUrl;
#     }
#
#     function secondDropdownChange() {
#         var pageUrl = "/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en";
#
#         var firstlistselect = $("#select-target-firstdropdownlist").attr('data-id');
#         var secondlistselect = $("#select-target-seconddropdownlist").attr('data-id');
#         pageUrl += (pageUrl.indexOf("?") != -1 ? "&" : "?") + "select=" + firstlistselect + "&option=" + secondlistselect;
#
#         window.parent.location = pageUrl;
#     }
#
#
# September 2018September 2018August 2018July 2018June 2018May 2018April 2018March 2018February 2018January 2018December 2017November 2017October 2017September 2017
#
#
# Highlights
# - Securities Market
#
# The average daily turnover for the first nine months of 2018 was $114.7 billion, an increase of 40 per cent when compared with $82.0 billion for the same period last year.
# The average daily turnover of derivative warrants for the first nine months of 2018 was $16.3 billion, an increase of 47 per cent when compared with $11.1 billion for the same period last year.
# The average daily turnover of CBBCs for the first nine months of 2018 was $7.2 billion, an increase of 64 per cent when compared with $4.4 billion for the same period last year.
# Funds raised through IPOs for the first nine months of 2018 was $242.7 billion, an increase of 177 per cent when compared with $87.6 billion for the same period last year.
# Total funds raised for the first nine months of 2018 was $445.9 billion, an increase of 41 per cent when compared with $316.6 billion for the same period last year.
# There were 166* newly listed companies for the first nine months of 2018, an increase of 46 per cent when compared with 114* for the same period last year.
#
#
# - Derivatives Market
#
# The average daily turnover of futures and options for the first nine months of 2018 was 1,197,645 contracts, an increase of 45 per cent when compared with the 823,469 contracts for the same period last year.
# The average daily turnover of equity index futures for the first nine months of 2018 was 493,358 contracts, an increase of 67 per cent when compared with the 294,951 contracts for the same period last year.
# The average daily turnover of RMB Currency Futures for the first nine months of 2018 was 7,436 contracts, an increase of 153 per cent when compared with the 2,940 contracts for the same period last year.
# On 14 September 2018, the open interest of RMB Currency Options – USD/CNH Options reached a record high of 10,827 contracts.
# On 26 September 2018, the open interest of Hang Seng China Enterprises Index Futures and Hang Seng China Enterprises Index Options reached a record high of 523,247 contracts and 3,631,457 contracts respectively.
#
# * Includes any transfers of listing from GEM to Main Board
#
# Listed Securities (Main Board and GEM)
# Month-end figures
#
#
#
#
#
#
#
# Sep 2018
#
#
# Sep 2017
#
#
# End 2017
#
#
#
#
#
#
# No. of listed companies
#
#
# 2,268
#
#
# 2,069
#
#
# 2,118
#
#
#
#
# Total market capitalisation ($Bil.)
#
#
# 32,166.6
#
#
# 31,412.4
#
#
# 33,998.8
#
#
#
#
# No. of newly listed companies *
#
#
# 16
#
#
# 11
#
#
# 174
#
#
#
#
# No. of listed securities
#
#
# 13,728
#
#
# 11,862
#
#
# 12,803
#
#
#
#
# No. of equity warrants
#
#
# 2
#
#
# 8
#
#
# 8
#
#
#
#
# No. of derivatives warrants
#
#
# 7,229
#
#
# 5,373
#
#
# 6,094
#
#
#
#
# No. of CBBCs
#
#
# 2,911
#
#
# 3,257
#
#
# 3,374
#
#
#
#
# No. of unit trusts
#
#
# 146
#
#
# 146
#
#
# 145
#
#
#
#
# No. of debt securities
#
#
# 1,155
#
#
# 996
#
#
# 1,047
#
#
#
#
# * Includes the number of transfer of listings from GEM to Main Board
#
#
# Securities Market Turnover (Main Board and GEM)
#
#
#
#
#
#
#
# Sep 2018
#
#
# Aug 2018
#
#
# % Change
#
#
#
#
#
#
# Monthly turnover ($Mil.) *
#
#
# 1,738,937
#
#
# 2,169,961
#
#
# -19.9%
#
#
#
#
# Average daily turnover by value ($Mil.) *
#
#
# 91,523
#
#
# 94,346
#
#
# -3.0%
#
#
#
#
# No. of trading days
#
#
# 19
#
#
# 23
#
#
# -
#
#
#
#
# * Turnover value for securities traded in non-Hong Kong dollar currency have been included
#
# Turnover by Type of Securities (Main Board and GEM)
#
#
#
#
#
#
#
# Sep 2018
#             ($Mil)
#
#
# Aug 2018
#             ($Mil)
#
#
# % Change
#
#
#
#
#
#
# Equities
#
#
# 1,282,869.81
#             (73.8%)
#
#
# 1,651,415.19
#             (76.1%)
#
#
# -22.3%
#
#
#
#
# Derivative warrants
#
#
# 250,470.16
#             (14.4%)
#
#
# 301,088.20
#             (13.9%)
#
#
# -16.8%
#
#
#
#
# CBBCs
#
#
# 128,471.06
#             (7.4%)
#
#
# 129,397.13
#             (6.0%)
#
#
# -0.7%
#
#
#
#
# Unit Trusts
# (include ETFs)
#
#
# 72,899.63
#             (4.2%)
#
#
# 82,442.81
#             (3.8%)
#
#
# -11.6%
#
#
#
#
# ( ) % of market total
# Turnover value for securities traded in non-Hong Kong dollar currency have been included
#
# ATS Transactions
# The total turnover of automated trading services’ (ATS) transactions for September 2018 was $27,820 million (1.6% of the securities market total turnover).
#
# Mainland Enterprises (Main Board and GEM)
# Month-end figures
#
#
#
#
#
#
#
# Sep 2018
#
#
# Sep 2017
#
#
# End 2017
#
#
#
#
#
#
# No. of H shares
#
#
# 261
#
#
# 249
#
#
# 252
#
#
#
#
# No. of Red chips Stocks
#
#
# 164
#
#
# 158
#
#
# 159
#
#
#
#
# No. of Mainland private enterprises
#
#
# 690
#
#
# 627
#
#
# 640
#
#
#
#
# Market capitalisation (% of market total)
#
#
# 67.6%
#
#
# 65.4%
#
#
# 66.2%
#
#
#
#
# Turnover value (% of equity turnover)
#
#
# 78.7%
#
#
# 77.7%
#
#
# 76.1%
#
#
#
#
#
# Index Performance
# Month-end figures
#
#
#
#
#
#
#
# Sep 2018
#
#
# % Change
#             over 1 Month
#
#
# % Change
#             over 12 Months
#
#
#
#
#
#
# S&P/HKEX LargeCap Index
#
#
# 36129.08
#
#
# -0.2%
#
#
# 2.1%
#
#
#
#
# S&P/HKEX GEM Index
#
#
# 183.21
#
#
# -8.1%
#
#
# -31.6%
#
#
#
#
# Hang Seng Index
#
#
# 27788.52
#
#
# -0.4%
#
#
# 0.9%
#
#
#
#
# Hang Seng China Enterprises Index
#
#
# 11017.87
#
#
# 1.3%
#
#
# 1.0%
#
#
#
#
# Hang Seng China-Affiliated Corporations Index*
#
#
# 4448.84
#
#
# 3.1%
#
#
# 3.5%
#
#
#
#
# CES China 120 Index ^
#
#
# 6304.51
#
#
# 2.6%
#
#
# 1.1%
#
#
#
#
# CESChina HK Mainland Index +
#
#
# 7604.83
#
#
# -0.4%
#
#
# 3.6%
#
#
#
#
# * - tracks Red chips
# ^ - tracks 80 Mainland-listed companies and 40 Hong Kong-listed Mainland enterprises
# + - tracks 40 Hong Kong-listed Mainland enterprises
#
# Derivatives Market Turnover
#
#
#
#
#
#
#
# Average Daily Volume (Contracts)
#
#
#
#
# Sep 2018
#
#
# Aug 2018
#
#
# % Change
#
#
#
#
#
#
# Total Futures
#
#
# 561,080
#
#
# 486,104
#
#
# 15.4%
#
#
#
#
# Hang Seng Index Futures
#
#
# 258,850
#
#
# 218,560
#
#
# 18.4%
#
#
#
#
# Mini Hang Seng Index Futures
#
#
# 105,496
#
#
# 87,827
#
#
# 20.1%
#
#
#
#
# Hang Seng China Enterprises Index Futures
#
#
# 158,389
#
#
# 143,073
#
#
# 10.7%
#
#
#
#
# Mini-Hang Seng China Enterprises Index Futures
#
#
# 20,285
#
#
# 18,573
#
#
# 9.2%
#
#
#
#
# HSI Dividend Point Index Futures
#
#
# 42
#
#
# 4
#
#
# 950.0%
#
#
#
#
# HSCEI Dividend Point Index Futures
#
#
# 2,766
#
#
# 1,005
#
#
# 175.2%
#
#
#
#
# HSI Volatility Index Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# MSCI AC Asia ex Japan NTR Index Futures
#
#
# 69
#
#
# 24
#
#
# 187.5%
#
#
#
#
# CES China 120 Index Futures
#
#
# 1
#
#
# 1
#
#
# 0.0%
#
#
#
#
# CES Gaming Top 10 Index Futures
#
#
# 0
#
#
# 1
#
#
# -100.0%
#
#
#
#
# Hang Seng Mainland Oil & Gas Index Futures
#
#
# 53
#
#
# 56
#
#
# -5.4%
#
#
#
#
# Hang Seng Mainland Banks Index Futures
#
#
# 19
#
#
# 13
#
#
# 46.2%
#
#
#
#
# Hang Seng Mainland Healthcare Index Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Hang Seng Mainland Properties Index Futures
#
#
# 142
#
#
# 183
#
#
# -22.4%
#
#
#
#
# Hang Seng IT Hardware Index Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Hang Seng Software & Services Index Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# IBOVESPA Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# MICEX Index Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# FTSE/JSE Top40 Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Stock Futures
#
#
# 6,439
#
#
# 4,419
#
#
# 45.7%
#
#
#
#
# 3-Month HIBOR Futures
#
#
# 6
#
#
# 1
#
#
# 500.0%
#
#
#
#
# 1-Month HIBOR Futures
#
#
# 1
#
#
# 0
#
#
# -
#
#
#
#
# RMB Currency Futures - USD/CNH Futures
#
#
# 7,408
#
#
# 10,784
#
#
# -31.3%
#
#
#
#
# RMB Currency Futures - EUR/CNH Futures
#
#
# 45
#
#
# 84
#
#
# -46.4%
#
#
#
#
# RMB Currency Futures - JPY/CNH Futures
#
#
# 8
#
#
# 19
#
#
# -57.9%
#
#
#
#
# RMB Currency Futures - AUD/CNH Futures
#
#
# 12
#
#
# 12
#
#
# 0.0%
#
#
#
#
# RMB Currency Futures - CNH/USD Futures
#
#
# 45
#
#
# 65
#
#
# -30.8%
#
#
#
#
# USD Gold Futures
#
#
# 984
#
#
# 1,341
#
#
# -26.6%
#
#
#
#
# CNH Gold Futures
#
#
# 9
#
#
# 20
#
#
# -55.0%
#
#
#
#
# Iron Ore Futures – Monthly Contracts
#
#
# 9
#
#
# 36
#
#
# -75.0%
#
#
#
#
# Iron Ore Futures – Quarterly Contracts
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# London Aluminium Mini Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# London Zinc Mini Futures
#
#
# 3
#
#
# 3
#
#
# 0.0%
#
#
#
#
# London Copper Mini Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# London Lead Mini Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# London Nickel Mini Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# London Tin Mini Futures
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Total Options
#
#
# 703,005
#
#
# 597,082
#
#
# 17.7%
#
#
#
#
# Hang Seng Index Options
#
#
# 57,180
#
#
# 45,919
#
#
# 24.5%
#
#
#
#
# Mini Hang Seng Index Options
#
#
# 10,377
#
#
# 8,247
#
#
# 25.8%
#
#
#
#
# Flexible Hang Seng Index Options
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Hang Seng China Enterprises Index Options
#
#
# 107,416
#
#
# 85,066
#
#
# 26.3%
#
#
#
#
# Mini-Hang Seng China Enterprises Index Options
#
#
# 1,739
#
#
# 1,262
#
#
# 37.8%
#
#
#
#
# Flexible Hang Seng China Enterprises Index Options
#
#
# 0
#
#
# 0
#
#
# -
#
#
#
#
# Stock Options
#
#
# 526,146
#
#
# 456,314
#
#
# 15.3%
#
#
#
#
# RMB Currency Futures - USD/CNH Options
#
#
# 147
#
#
# 274
#
#
# -46.4%
#
#
#
#
# Total Futures and Options
#
#
# 1,264,085
#
#
# 1,083,186
#
#
# 16.7%
#
#
#
#
#
# Clearing and Settlement
#
#
#
#
# CCASS Statistics (securities market)
#
#
# Sep 2018
#
#
# Aug 2018
#
#
# % Change
#
#
#
#
#
#
# Average daily number of exchange trades settled by CCASS
#
#
# 1,474,647
#
#
# 1,526,623
#
#
# -3.40%
#
#
#
#
# Average daily number of settlement instructions (SIs) settled by CCASS
#
#
# 97,957
#
#
# 93,572
#
#
# 4.69%
#
#
#
#
# Average daily number of investor SIs (ISIs) settled by CCASS
#
#
# 257
#
#
# 267
#
#
# -3.75%
#
#
#
#
# Average daily settlement efficiency of CNS stock positions on due day (T+2)
#
#
# 99.89
#
#
# 99.93
#
#
# N/A
#
#
#
#
# Shares deposited in the CCASS depository
#  – % of total issued shares
#  – % of the total market capitalisation
#
#
#
#             75.87
# 58.33
#
#
#
#             75.80
# 58.97
#
#
#
#             N/A
# N/A
#
#
#
#
# DCASS Statistics (derivatives market)
#
#
# Sep 2018
#
#
# Aug 2018
#
#
# % Change
#
#
#
#
# Month-end Open Interest (contracts)
#
#
#
#
#
#
#
#
#
#
#
#
#
# – Equity Index Futures
#
#
# 673,906
#
#
# 642,951
#
#
# 4.8%
#
#
#
#
# – Stock Futures
#
#
# 18,058
#
#
# 24,464
#
#
# -26.2%
#
#
#
#
# – Interest Rates Futures
#
#
# 415
#
#
# 456
#
#
# -9.0%
#
#
#
#
# – RMB Currency Futures
#
#
# 33,334
#
#
# 38,851
#
#
# -14.2%
#
#
#
#
# – Gold Futures
#
#
# 246
#
#
# 375
#
#
# -34.4%
#
#
#
#
# – Iron Ore Futures
#
#
# 426
#
#
# 322
#
#
# 32.3%
#
#
#
#
# – London Metal Mini Futures
#
#
# 4
#
#
# 9
#
#
# -55.6%
#
#
#
#
# – Equity Index Options
#
#
# 3,321,193
#
#
# 3,609,789
#
#
# -8.0%
#
#
#
#
# – Stock Options
#
#
# 8,465,878
#
#
# 10,313,958
#
#
# -17.9%
#
#
#
#
# – RMB Currency Options
#
#
# 8,689
#
#
# 10,126
#
#
# -14.2%
#
#
#
#
#
# Year-to-date Statistics
#
#
#
#
# Securities Market
#
#
# Sep 2018
# YTD
#
#
# Sep 2017
# YTD
#
#
# % Change
#
#
#
#
#
#
# No. of newly listed companies #
#
#
# 166
#
#
# 114
#
#
# 45.6%
#
#
#
#
# Average daily turnover by value ($Mil.) ^
#
#
# 114,734
#
#
# 81,971
#
#
# 40.0%
#
#
#
#
# Average share traded per trading day (Mil. Shares)
#
#
# 219,883
#
#
# 174,617
#
#
# 25.9%
#
#
#
#
# Average no. of trades per trading day
#
#
# 1,648,034
#
#
# 1,186,506
#
#
# 38.9%
#
#
#
#
# Fund raised by IPOs ($Mil.)
#
#
# 242,673
#
#
# 87,574
#
#
# 177.1%
#
#
#
#
# Total funds raised (including IPOs) ($Mil.)*
#
#
# 445,914
#
#
# 316,561
#
#
# 40.9%
#
#
#
#
# Derivatives Market
#
#
# Sep 2018
#             YTD
#
#
# Sep 2017
#             YTD
#
#
# % Change
#
#
#
#
# Average daily volume (contracts)
#
#
#
#
#
#
#
#
#
#
#
#
#
# – Equity Index Futures
#
#
# 493,358
#
#
# 294,951
#
#
# 67.3%
#
#
#
#
# – Stock Futures
#
#
# 2,551
#
#
# 522
#
#
# 388.7%
#
#
#
#
# – 5-Year MOF T-Bond Futures
#
#
# -
#
#
# 70
#
#
# -
#
#
#
#
# – Interest Rates Futures
#
#
# 4
#
#
# 2
#
#
# 100.0%
#
#
#
#
# – RMB Currency Futures
#
#
# 7,436
#
#
# 2,940
#
#
# 152.9%
#
#
#
#
# – Gold Futures
#
#
# 1,363
#
#
# 756
#
#
# 80.3%
#
#
#
#
# – Iron Ore Futures
#
#
# 28
#
#
# -
#
#
# -
#
#
#
#
# – London Metal Mini Futures
#
#
# 8
#
#
# 11
#
#
# -27.3%
#
#
#
#
# – Equity Index Options
#
#
# 158,820
#
#
# 128,215
#
#
# 23.9%
#
#
#
#
# – Stock Options
#
#
# 533,972
#
#
# 396,491
#
#
# 34.7%
#
#
#
#
# – RMB Currency Options
#
#
# 105
#
#
# 67
#
#
# 56.7%
#
#
#
#
# Clearing & Settlement
#
#
# Sep 2018
#             YTD
#
#
# Sep 2017
#             YTD
#
#
# % Change
#
#
#
#
# Average daily number of exchange trades handled by CCASS
#
#
# 1,647,388
#
#
# 1,185,894
#
#
# 38.92%
#
#
#
#
# Average daily number of settlement instructions (SIs) settled by CCASS
#
#
# 104,224
#
#
# 89,413
#
#
# 16.56%
#
#
#
#
# Average daily number of investor SIs (ISIs) settled by CCASS
#
#
# 334
#
#
# 330
#
#
# 1.21%
#
#
#
#
# # Includes the number of transfer of listings from GEM to Main Board
# ^ Turnover value for traded in non-HKD currency securities have been included
# * Provisional figures only
#
# Historical Records
# up to 30 September 2018
# Top 10 Hang Seng Index Closes
#
#
#
#
# Rank
#
#
# Date
#
#
# Close
#
#
#
#
#
#
# 1
#
#
# 2018/01/26
#
#
# 33154.12
#
#
#
#
# 2
#
#
# 2018/01/29
#
#
# 32966.89
#
#
#
#
# 3
#
#
# 2018/01/24
#
#
# 32958.69
#
#
#
#
# 4
#
#
# 2018/01/23
#
#
# 32930.70
#
#
#
#
# 5
#
#
# 2018/01/31
#
#
# 32887.27
#
#
#
#
# 6
#
#
# 2018/01/25
#
#
# 32654.45
#
#
#
#
# 7
#
#
# 2018/02/01
#
#
# 32642.09
#
#
#
#
# 8
#
#
# 2018/01/30
#
#
# 32607.29
#
#
#
#
# 9
#
#
# 2018/02/02
#
#
# 32601.78
#
#
#
#
# 10
#
#
# 2018/01/22
#
#
# 32393.41
#
#
#
#
#
# Top 10 Daily Market Turnover
# (Main Board and GEM)
#
#
#
#
# Rank
#
#
# Date
#
#
# Turnover ($)
#
#
#
#
#
#
# 1
#
#
# 2015/04/09
#
#
# 293,910,756,648
#
#
#
#
# 2
#
#
# 2018/03/23
#
#
# 284,101,947,853
#
#
#
#
# 3
#
#
# 2015/04/13
#
#
# 266,098,632,854
#
#
#
#
# 4
#
#
# 2018/02/06
#
#
# 258,799,618,543
#
#
#
#
# 5
#
#
# 2015/04/08
#
#
# 252,396,050,844
#
#
#
#
# 6
#
#
# 2015/04/14
#
#
# 239,903,336,931
#
#
#
#
# 7
#
#
# 2015/07/08
#
#
# 237,429,139,110
#
#
#
#
# 8
#
#
# 2015/04/10
#
#
# 222,888,834,174
#
#
#
#
# 9
#
#
# 2018/02/09
#
#
# 219,595,292,569
#
#
#
#
# 10
#
#
# 2018/02/07
#
#
# 218,890,883,115
#
#
#
#
#
# Top 10 Market Capitalisation
# (Main Board and GEM)
#
#
#
#
# Rank
#
#
# Date
#
#
# Market Capitalisation ($)
#
#
#
#
#
#
# 1
#
#
# 2018/01/26
#
#
# 37,715,721,713,817
#
#
#
#
# 2
#
#
# 2018/01/29
#
#
# 37,498,267,978,409
#
#
#
#
# 3
#
#
# 2018/01/24
#
#
# 37,458,993,282,123
#
#
#
#
# 4
#
#
# 2018/01/23
#
#
# 37,434,956,503,062
#
#
#
#
# 5
#
#
# 2018/01/31
#
#
# 37,196,824,130,391
#
#
#
#
# 6
#
#
# 2018/01/25
#
#
# 37,171,558,627,632
#
#
#
#
# 7
#
#
# 2018/01/30
#
#
# 37,034,857,609,118
#
#
#
#
# 8
#
#
# 2018/02/02
#
#
# 36,948,839,611,393
#
#
#
#
# 9
#
#
# 2018/02/01
#
#
# 36,943,877,577,778
#
#
#
#
# 10
#
#
# 2018/01/22
#
#
# 36,925,559,142,548
#
#
#
#
#
# Record High for Top-10 Derivatives Market Products (Based on Contract Volume)
#
#
#
#
# Product
#
#
# Record High Daily Volume
#
#
# Record High Open Interest
#
#
#
#
#
#
#
#
#
# Contracts
#
#
# Date
#
#
# Contracts
#
#
# Date
#
#
#
#
# Stock Options
#
#
# 1,221,324
#
#
# 2015/04/13
#
#
# 13,725,731
#
#
# 2018/03/27
#
#
#
#
# Hang Seng China Enterprises Index Futures
#
#
# 467,559
#
#
# 2015/08/26
#
#
# 523,247
#
#
# 2018/09/26
#
#
#
#
# Hang Seng Index Futures
#
#
# 421,806
#
#
# 2018/06/26
#
#
# 206,082
#
#
# 2017/06/27
#
#
#
#
# Hang Seng China Enterprises Index Options
#
#
# 232,994
#
#
# 2018/02/09
#
#
# 3,631,457
#
#
# 2018/09/26
#
#
#
#
# Mini Hang Seng Index Futures
#
#
# 215,927
#
#
# 2018/02/07
#
#
# 21,682
#
#
# 2011/06/17
#
#
#
#
# Hang Seng Index Options
#
#
# 130,998
#
#
# 2018/01/23
#
#
# 594,941
#
#
# 2017/11/28
#
#
#
#
# Mini-Hang Seng China Enterprises Index Futures
#
#
# 76,471
#
#
# 2018/02/06
#
#
# 16,436
#
#
# 2014/12/11
#
#
#
#
# Stock Futures
#
#
# 27,966
#
#
# 2007/03/28
#
#
# 47,050
#
#
# 2013/03/27
#
#
#
#
# HSCEI Dividend Point Index Futures
#
#
# 27,501
#
#
# 2017/02/14
#
#
# 184,626
#
#
# 2016/12/13
#
#
#
#
# RMB Currency Futures - USD/CNH Futures
#
#
# 22,105
#
#
# 2018/08/06
#
#
# 46,711
#
#
# 2017/01/04
#
#
#
#
#
#
# Updated 30 Sep 2018
#
#
#
#
#
#
#
#
#
#
#
#                 if (browserAllow()) {
#                     document.write('<ul class="footer__social-icons"><li><a href="https://twitter.com/hkexgroup" Title="Follow on Twitter" Target="_blank"><img src="/images/HKEX/HKEX MARKET/twitter.svg" alt="Follow on Twitter"></a></li><li><a href="https://www.linkedin.com/company/hkex" Title="Follow on LinkedIn" Target="_blank"><img src="/images/HKEX/HKEX MARKET/linkedin.svg" alt="Follow on LinkedIn"></a></li><li><a href="/Global/Follow-Us-on-WeChat?sc_lang=en" Title="Follow on WeChat" Target="_self"><img src="/images/HKEX/HKEX MARKET/wechat.svg" alt="Follow on WeChat"></a></li><li><a href="https://www.youtube.com/user/hkexgroup" Title="Follow on YouTube" Target="_blank"><img src="/images/HKEX/HKEX MARKET/youtube.svg" alt="Follow on YouTube"></a></li><li><a href="https://www.weibo.com/6508212764" Title="Follow on Weibo" Target="_blank"><img src="/-/media/Market-System/Social-Media-Icon/weibo.png?as=1&hash=374023C02ABCB9CBD8F949DE1FD265AA25A4A8C3" alt="Weibo "></a></li></ul>');
#                 }
#
#
#
# ContactCareerFAQSitemapGlossaryDisclaimerHyperlink PolicyPrivacy PolicyWebsite TutorialsRSS
#
#
#
#                 ©2017-18 Hong Kong Exchanges and Clearing Limited. All rights reserved.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	    $(document).ready(function () {
# 	        antiClickJack();
# 	    });
#
# 	    //anti clickjack function goes here
# 	    function antiClickJack() {
# 	        var isFramed = self != top;
# 	        var currentDomain = window.location.host;
# 	        //check if the application sites navigate within themselves
# 	        //then antiClickJack should have no effect
# 	        var navigateWithinDomain = window.parent.location.href.toString().indexOf(currentDomain) != -1;
# 	        if (navigateWithinDomain == false) {
# 	            $("body").css("display", "none");
# 	            return;
# 	        }
#
# 	        if (isFramed) {
# 	            var url = document.referrer;
# 	            var acceptedHostFrame = isHostFrameAllowed(url);
# 	            if (!acceptedHostFrame) {
# 	                $("body").css("display", "none");
# 	                //alert("accepted host");
# 	            } else {
# 	                return;
# 	            }
# 	        }
# 	    }
#
# 	    function isHostFrameAllowed(targetHostFrame) {
# 	        var hostframes = "www.hkgem.com,www.hkex.com.hk,www.hkexgroup.com,sc.hkex.com.hk,sc.hkexnews.hk,www.hkexnews.hk";
# 	        if (hostframes.length == 0) {
# 	            return true;
# 	        }
# 	        var hosts = hostframes.split(",");
# 	        for (var i = 0; i < hosts.length; i++) {
# 	            if (targetHostFrame.indexOf(hosts[i]) > -1) {
# 	                return true;
# 	            }
# 	        }
# 	        return false;
# 	    }

# %%
for url in soup.find_all('a'):
    print(url.get('href'))
# Out:
# #skip-to-content
# /?sc_lang=en
# #
# #
# #
# #
# http://www.hkexgroup.com/about-hkex/company-information/about-hkex?sc_lang=en
# http://www.hkexgroup.com/brand/en/index.htm
# http://www.hkexgroup.com/About-HKEX/Organisation/Board-and-Committees?sc_lang=en
# http://www.hkexgroup.com/Investor-Relations?sc_lang=en
# http://www.hkexgroup.com/Investor-Relations/Regulatory-Disclosure/Regulatory-Reports/2017?sc_lang=en
# http://www.hkexgroup.com/Investor-Relations?sc_lang=en
# http://www.hkexgroup.com/Corporate-Governance?sc_lang=en
# http://www.hkexgroup.com/Corporate-Social-Responsibility?sc_lang=en
# /Global/About/Visit-HKEX?sc_lang=en
# http://www.hkexgroup.com/About-HKEX/Careers?sc_lang=en
# #
# https://www.lme.com/
# http://www.hkexgroup.com/
# http://www.hkgem.com/root/e_default.asp
# http://www.hkexnews.hk/
# https://www.cesc.com/en/index.html
# http://www.chinabondconnect.com/en/index.htm
# javascript:route('/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-hk', 'zh-HK')
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-cn
# javascript:void(0);
# /?sc_lang=en
# #
# /Market-Data/Securities-Prices/Equities?sc_lang=en
# /Market-Data/Securities-Prices/Exchange-Traded-Products?sc_lang=en
# /Market-Data/Securities-Prices/Derivative-Warrants?sc_lang=en
# /Market-Data/Securities-Prices/Callable-Bull-Bear-Contracts?sc_lang=en
# /Market-Data/Securities-Prices/Real-Estate-Investment-Trusts?sc_lang=en
# /Market-Data/Securities-Prices/Debt-Securities?sc_lang=en
# /Market-Data/Futures-and-Options-Prices/Equity-Index/Hang-Seng-Index-Futures-and-Options?sc_lang=en
# /Market-Data/Futures-and-Options-Prices/Single-Stock/All?sc_lang=en
# /Market-Data/Futures-and-Options-Prices/Foreign-Exchange/CUS---USD_CNH-Futures-and-Options?sc_lang=en
# /Market-Data/Futures-and-Options-Prices/Interest-Rate/One-Month-HIBOR-Futures?sc_lang=en
# /Market-Data/Futures-and-Options-Prices/Commodities/Gold-Futures?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# /Market-Data/Statistics/Securities-Market?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market?sc_lang=en
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository?sc_lang=en
# /Market-Data/HKEX-News?sc_lang=en
# /Market-Data/News-Alerts?sc_lang=en
# /Services/Market-Data-Services?sc_lang=en
# /Market-Data/HKEX-News?sc_lang=en
# /Market-Data/HKEX-News?sc_lang=en
# /Market-Data/News-Alerts?sc_lang=en
# /Market-Data/News-Alerts?sc_lang=en
# /Services/Market-Data-Services?sc_lang=en
# /Services/Market-Data-Services?sc_lang=en
# #
# /Products/Securities/Equities?sc_lang=en
# /Products/Securities/Exchange-Traded-Products/Overview?sc_lang=en
# /Products/Securities/Derivative-Warrants?sc_lang=en
# /Products/Securities/Callable-Bull-Bear-Contracts?sc_lang=en
# /Products/Securities/Real-Estate-Investment-Trusts?sc_lang=en
# /Products/Securities/Debt-Securities?sc_lang=en
# /Products/Listed-Derivatives/Equity-Index/Hang-Seng-Index-(HSI)/Hang-Seng-Index-Futures?sc_lang=en
# /Products/Listed-Derivatives/Single-Stock/Stock-Futures?sc_lang=en
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Futures?sc_lang=en
# /Products/Listed-Derivatives/Interest-Rate/Three-Months-HIBOR-Futures?sc_lang=en
# /Products/Listed-Derivatives/Commodities/Gold-Futures?sc_lang=en
# /Products/OTC-Derivatives/Eligible-OTC-Clear-Products?sc_lang=en
# /Products/OTC-Derivatives/Interest-Rate-Swaps?sc_lang=en
# /Products/OTC-Derivatives/Non-Deliverable-Forwards?sc_lang=en
# /Products/OTC-Derivatives/Cross-Currency-Swaps?sc_lang=en
# /Products/OTC-Derivatives/Deliverable-FX?sc_lang=en
# /Products/Find-a-Partner?sc_lang=en
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
# /Products/Find-a-Partner?sc_lang=en
# /Products/Find-a-Partner?sc_lang=en
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
# /Products/Listed-Derivatives/Commodities/Gold-Futures/USD-Gold-Futures?sc_lang=en
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
# /Products/Listed-Derivatives/Foreign-Exchange/USD-CNH-Options?sc_lang=en
# #
# /Services/Trading/Securities/Overview/Trading-Mechanism?sc_lang=en
# /Services/Trading/Securities/Infrastructure/Overview?sc_lang=en
# /Services/Trading/Derivatives/Overview/Trading-Mechanism?sc_lang=en
# /Services/Trading/Derivatives/Infrastructure/HKATS?sc_lang=en
# /Services/Connectivity/Hosting-Services?sc_lang=en
# /Services/Connectivity/SDNet-2?sc_lang=en
# /Services/Market-Data-Services/Real-Time-Data-Services/Overview?sc_lang=en
# /Services/Market-Data-Services/Historical-Data-Services?sc_lang=en
# /Services/Market-Data-Services/Infrastructure?sc_lang=en
# /Services/Rules-and-Forms-and-Fees/Rules/Overview?sc_lang=en
# /Services/Rules-and-Forms-and-Fees/Forms/Overview?sc_lang=en
# /Services/Rules-and-Forms-and-Fees/Fees/Overview?sc_lang=en
# /Services/Clearing/Securities/Overview?sc_lang=en
# /Services/Clearing/Securities/Infrastructure?sc_lang=en
# /Services/Clearing/Securities/Risk-Management?sc_lang=en
# /Services/Clearing/Securities/PFMI?sc_lang=en
# /Services/Clearing/Listed-Derivatives/Overview?sc_lang=en
# /Services/Clearing/Listed-Derivatives/Infrastructure?sc_lang=en
# /Services/Clearing/Listed-Derivatives/Risk-Management?sc_lang=en
# /Services/Clearing/Listed-Derivatives/PFMI?sc_lang=en
# /Services/Clearing/OTC-Clear/Overview/Clearing-Services?sc_lang=en
# /Services/Clearing/OTC-Clear/Infrastructure?sc_lang=en
# /Services/Clearing/OTC-Clear/Risk-Management?sc_lang=en
# /Services/Clearing/OTC-Clear/PFMI?sc_lang=en
# /Services/Settlement-and-Depository/Settlement?sc_lang=en
# /Services/Settlement-and-Depository/Depository?sc_lang=en
# /Services/Settlement-and-Depository/Common-Nominee-Services?sc_lang=en
# /Services/Settlement-and-Depository/Securities-Admission-into-CCASS?sc_lang=en
# /Services/Clearing/Securities/PFMI?sc_lang=en
# /Services/Next-Generation-Post-Trade-Programme/Overview?sc_lang=en
# /Services/Next-Generation-Post-Trade-Programme/NextGen-Risk-Management?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /Services/Become-a-Participant?sc_lang=en
# /Services/Market-Open-Ceremony?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /Services/Become-a-Participant?sc_lang=en
# /Services/Become-a-Participant?sc_lang=en
# /Services/Market-Open-Ceremony?sc_lang=en
# /Services/Market-Open-Ceremony?sc_lang=en
# #
# /Listing/Why-List-in-Hong-Kong?sc_lang=en
# /Listing/Getting-Started?sc_lang=en
# /Listing/How-We-Regulate/Overview?sc_lang=en
# /Listing/Rules-and-Guidance/Whats-New?sc_lang=en
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
# /Listing/Getting-Started/Listing-in-HK?sc_lang=en
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
# /Listing/Rules-and-Guidance/Listing-Rules?sc_lang=en
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
# /Listing/Rules-and-Guidance/Other-Resources/New-Applicants/Contact-Persons-in-HKEX-Listing-Department-for-Pre-IPO-Enquiry-and-IPO-Processing?sc_lang=en
# #
# /News/News-Release?sc_lang=en
# /News/Market-Consultations/2016-to-Present?sc_lang=en
# /News/Tender-Notices/Tender-Notices?sc_lang=en
# /News/Research-Reports/HKEX-Surveys/HKEX-Surveys?sc_lang=en
# http://www.hkexgroup.com/Media-Centre?sc_lang=en
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /News/HKEX-Calendar?sc_lang=en
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
# http://www.hkexgroup.com/Media-Centre/Charles-Li-Direct?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /Services/Circulars-and-Notices/Participant-and-Members-Circulars?sc_lang=en
# /News/HKEX-Calendar?sc_lang=en
# /News/HKEX-Calendar?sc_lang=en
# #
# /Mutual-Market/Stock-Connect?sc_lang=en
# http://www.chinabondconnect.com
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
# /Mutual-Market/Stock-Connect/Statistics/Historical-Daily?sc_lang=en
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
# /Mutual-Market/Stock-Connect/Statistics/Hong-Kong-and-Mainland-Market-Highlights?sc_lang=en
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
# /Mutual-Market/Stock-Connect/Eligible-Stocks/View-All-Eligible-Securities?sc_lang=en
# None
# javascript:route('/Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-hk', 'zh-HK')
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=zh-cn
# ../../../layouts/HKEX/HKEX%20MARKET/#
# ../../../layouts/HKEX/HKEX%20MARKET/#
# ../../../layouts/HKEX/HKEX%20MARKET/#
# ../../../layouts/HKEX/HKEX%20MARKET/#
# ../../../layouts/HKEX/HKEX%20MARKET/#
# javascript:void(0);
# None
# #
# #
# /Market-Data/Statistics/Consolidated-Reports?sc_lang=en
# #
# #
# /Market-Data/Statistics/Consolidated-Reports?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Monthly-Market-Highlights?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Securities-and-Derivatives-Markets-Quarterly-Report?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/HKEX-Fact-Book?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/Monthly-Bulletin?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/Trading-value,-volume-and-number-of-deals/2015-to-2018-(up-to-the-end-of-previous-month)?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/Market-capitalisation/2015-to-2018-(up-to-the-end-of-previous-month)_mc?sc_lang=en
# /Market-Data/Statistics/Consolidated-Reports/Securities-Statistics-Archive/S,-a-,P-HKEX-LargeCap-Index-daily-closing/2018-(up-to-the-end-of-previous-month)_sp?sc_lang=en
# http://www.hkgem.com/statistics/e_default.htm
# /Market-Data/Statistics/Consolidated-Reports/China-Dimension?sc_lang=en
# /Market-Data/Statistics/Securities-Market?sc_lang=en
# /-/media/HKEX-Market/Market-Data/Statistics/Securities-Market/Funds-Raised-by-Type/fun_type_e.pdf
# /Market-Data/Statistics/Securities-Market/Placings?sc_lang=en
# /Market-Data/Statistics/Securities-Market/Takeovers?sc_lang=en
# /eng/stat/smstat/dayquot/qtn.asp
# /Market-Data/Statistics/Securities-Market/Short-Selling-Turnover-Today?sc_lang=en
# /eng/stat/smstat/ssturnover/ncms/mshtmain.htm
# /eng/stat/smstat/ssturnover/ncms/mshtgem.htm
# /eng/stat/smstat/ssturnover/ncms/mshten.htm
# /eng/stat/smstat/ssturnover/ncms/ashtmain.htm
# /eng/stat/smstat/ssturnover/ncms/ashtgem.htm
# /eng/stat/smstat/ssturnover/ncms/ashten.htm
# /eng/vcm/vcmtriggersecurity.aspx
# /Market-Data/Statistics/Derivatives-Market?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Derivatives-Market-Highlights?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Daily-Statistics?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Monthly-Statistics?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Yearly-Statistics?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Record-High?sc_lang=en
# /eng/vcm/vcmtriggerderivative.aspx
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/Derivatives-Market?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/USD-CNH-Futures?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Market-Research-Reports/FIC-Monthly-Newsletter?sc_lang=en
# /Market-Data/Statistics/Derivatives-Market/Daily-Market-Report-(Latest)?sc_lang=en
# /eng/stat/dmstat/dayrpt/dmrcalendar.asp
# /eng/stat/dmstat/dayrpt/stkoptexe.htm
# /eng/stat/dmstat/wqtn.asp
# /Market-Data/Statistics/Derivatives-Market/Market-Share-Data-on-HSI-Futures?sc_lang=en
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# /Market-Data/Statistics/Participant/Stock-Exchange-Participants'-Market-Share-Report?sc_lang=en
# /Market-Data/Statistics/Participant/Exchange-Participant-Data?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Clearing-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Margin-Requirement?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Settlement-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Stock-Admission-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics/Listed-Derivatives-Margin-Requirement?sc_lang=en
# /eng/stat/dmstat/oi/oi_f.asp
# /eng/stat/dmstat/oi/oi_o.asp
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Listed-Derivatives-Clearing-Statistics/Data-Download?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics/Monthly-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/OTC-Clearing-and-Settlement-Statistics/Yearly-Statistics?sc_lang=en
# /Market-Data/Statistics/Clearing-and-Settlement-and-Depository/Securities-Depository-Statistics?sc_lang=en
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# https://www.hkex.com.hk/-/media/HKEX-Market/Services/Rules-and-Forms-and-Fees/Rules/SEHK/Securities/Rules/chap_1_eng.pdf?la=en
# /?sc_lang=en
# /Global/Exchange/Contact?sc_lang=en
# http://www.hkexgroup.com/About-HKEX/Careers
# /Global/Exchange/FAQ/Top-Questions?sc_lang=en
# /Global/Exchange/Sitemap?sc_lang=en
# /Global/Exchange/Glossary?sc_lang=en
# /Global/Exchange/Disclaimer?sc_lang=en
# /Global/Exchange/Hyperlink-Policy?sc_lang=en
# /Global/Exchange/Privacy-Policy?sc_lang=en
# /Global/Exchange/Website-Tutorials?sc_lang=en
# /Services/RSS-Feeds?sc_lang=en
